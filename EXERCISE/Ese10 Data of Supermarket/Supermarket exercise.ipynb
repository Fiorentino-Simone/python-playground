# %%
#per visualizzare tutti i file nella directory
import os;
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Supermarket exercise.ipynb',
#  'supermarkets-commas-withoutHeader.txt',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
#adesso con jupyter si avrà una visualizzazione migliore dei dati
#gestiti e manipolati tramite la libreria pandas
df1=pandas.read_csv("supermarkets.csv")
#ora stampiamo i valori, non serve il print
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#TRAMITE QUINDI PANDAS E PYTHON SI POSSONO FARE MOLTE OPERAZIONI CON I DATI COME:
#merge di colonne
#aggiungere colonne
#spostare dati da una colonna ad un altra
#esportare i dati in diversi formati come: CSV, EXCEL o JSON

# %%
#per leggere dei json con PANDAS si usa read_json 
df1 = pandas.read_json("supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#per utilizzare/caricare dei file EXCEL dobbiamo scaricare per forza delle dipendenze di pandas, come:
#pip3.10 install openpyxl per i file in .xlsx
#pip3.10 install xlrd per i file in .xls

# %%
#inserisce l'ID come indice
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#invece per visualizzare gli excel come dicevamo prima bisagna fare:
df2 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)
#bisogna anche specificare il foglio del file excel da utilizzare
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
#per quanto riguarda la visualizzazione dei dati con i txt file, si usa lo stesso dei csv (siccome si usano anche li le virgole)
df3 = pandas.read_csv("supermarkets-commas.txt");
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#per invece lavorare con dei file che hanno altri separatori, bisogna passarlo come parametro alla funzione read_csv
df4 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";");
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#PER QUANTO RIGUARDA LE COLONNE:
#a volte possiamo trovare dei file senza, e per non lasciarli senza intestazione possiamo avvisare python che quel determinato file non presenta l'intestazione
df5 = pandas.read_csv("supermarkets-commas-withoutHeader.txt", header=None);
df5
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
#per andare a settare le intestazioni bisogna:
df5.columns = ["ID","Address","City","ZIP","Country","Name","Employees"]
df5
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_json("supermarkets.json")
df6 = df6.set_index("ID")
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#per estrapolare una parte dei dati della tabella si usa la loc
#inserendo proprio la porzione 
df6.loc[2:4,"City":"Name"]
# Out:
#              City             State Country         Name
# ID
# 2   San Francisco          CA 94119     USA  Bready Shop
# 3   San Francisco  California 94114     USA  Super River
# 4   San Francisco          CA 94114     USA   Ben's Shop

# %%
#anche singolo come
df6.loc[:,"Country"]
# Out:
# ID
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# Name: Country, dtype: object

# %%
#normalmente però si fa l'accesso CON GLI INDICI
df6.iloc[1:3,1:3]
# Out:
#              City             State
# ID
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114

# %%
#per eliminare una colonna bisogna procedere inserendo il nome e 1
df6.drop("City",1)
# Out:
# C:\Users\simof\AppData\Local\Temp\ipykernel_38056\4133896194.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df6.drop("City",1)
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
#per le righe si mette il nome della riga e poi 0 come secondo parametro
df6 = df6.drop(2,0)
# Out:
# C:\Users\simof\AppData\Local\Temp\ipykernel_38056\1560122013.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df6 = df6.drop(2,0)

# %%
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#multiplo invece:
df6.drop(df6.columns[0:3],1)
# Out:
# C:\Users\simof\AppData\Local\Temp\ipykernel_38056\2561363556.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df6.drop(df6.columns[0:3],1)
#    Country         Name  Employees
# ID
# 1      USA      Madeira          8
# 3      USA  Super River         25
# 4      USA   Ben's Shop         10
# 5      USA      Sanchez         12
# 6      USA   Richvalley         20

# %%
len(df6.index)
# Out:
# 5

# %%
#per aggiungere una nuova colonna con dei nuovi dati bisogna assegnarla
df6["Continent"] = ["North america", "South america", "South america", "South america", "South america"]

# %%
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North america
# 3          25  South america
# 4          10  South america
# 5          12  South america
# 6          20  South america

# %%
#aggiornare una già esistente
df6["Continent"] = df6["Country"] + "," + "North America"

# %%
df6
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees          Continent
# ID
# 1           8  USA,North America
# 3          25  USA,North America
# 4          10  USA,North America
# 5          12  USA,North America
# 6          20  USA,North America

# %%
#per aggiungere una nuova riga bisogna per forza eseguire un metodo di TRANSFORM:
df6_t = df6.T
df6_t["My Address"] = ["My City", "My Country", 10, 7, "My Shop", "My State", "My Continent"]
df6_t
# Out:
# ID                         1                  3                  4  \
# Address         3666 21st St        332 Hill St       3995 23rd St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114   California 94114           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Super River         Ben's Shop
# Employees                  8                 25                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         5                  6    My Address
# Address      1056 Sanchez St    551 Alvarado St       My City
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# Name                 Sanchez         Richvalley       My Shop
# ...

# %%
#siccome l'ha aggiunta come colonna adesso andiamo a trasformarla di nuovo andandolo ad aggiungere in riga
df6 = df6_t.T
df6
# Out:
#                     Address           City             State Country  \
# ID
# 1              3666 21st St  San Francisco          CA 94114     USA
# 3               332 Hill St  San Francisco  California 94114     USA
# 4              3995 23rd St  San Francisco          CA 94114     USA
# 5           1056 Sanchez St  San Francisco        California     USA
# 6           551 Alvarado St  San Francisco          CA 94114     USA
# My Address          My City     My Country                10       7
#
#                    Name Employees          Continent
# ID
# 1               Madeira         8  USA,North America
# 3           Super River        25  USA,North America
# 4            Ben's Shop        10  USA,North America
# 5               Sanchez        12  USA,North America
# 6            Richvalley        20  USA,North America
# My Address      My Shop  My State       My Continent
